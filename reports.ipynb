# %%
import utils 
X_train, X_test, y_train, y_test = utils.get_splits()

# %%
dt = utils.get_model("best_decision_tree")
dt.fit(X_train, y_train)
utils.evaluate_trained_model(dt, X_train, y_train, "results/best_decision_tree", is_test=False, do_cross=False)
utils.evaluate_trained_model(dt, X_test, y_test, "results/best_decision_tree", is_test=True, do_cross=False)
# Out:
# classification train set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000    227565
#            1     1.0000    1.0000    1.0000    227339
#
#     accuracy                         1.0000    454904
#    macro avg     1.0000    1.0000    1.0000    454904
# weighted avg     1.0000    1.0000    1.0000    454904
# classification test set
#               precision    recall  f1-score   support
#
#            0     0.9987    0.9973    0.9980     56750
#            1     0.9973    0.9987    0.9980     56976
#
#     accuracy                         0.9980    113726
#    macro avg     0.9980    0.9980    0.9980    113726
# weighted avg     0.9980    0.9980    0.9980    113726

# %%
rf = utils.get_model("best_random_forest")
rf.fit(X_train, y_train)
utils.evaluate_trained_model(rf, X_train, y_train, "results/best_random_forest", is_test=False, do_cross=False)
utils.evaluate_trained_model(rf, X_test, y_test, "results/best_random_forest", is_test=True, do_cross=False)
# Out:
# classification train set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000    227565
#            1     1.0000    1.0000    1.0000    227339
#
#     accuracy                         1.0000    454904
#    macro avg     1.0000    1.0000    1.0000    454904
# weighted avg     1.0000    1.0000    1.0000    454904
# classification test set
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9997    0.9999     56750
#            1     0.9997    1.0000    0.9999     56976
#
#     accuracy                         0.9999    113726
#    macro avg     0.9999    0.9999    0.9999    113726
# weighted avg     0.9999    0.9999    0.9999    113726

# %%
stacking = utils.get_model("best_stacking")
stacking.fit(X_train, y_train)
utils.evaluate_trained_model(stacking, X_train, y_train, "results/best_stacking", is_test=False, do_cross=False)
utils.evaluate_trained_model(stacking, X_test, y_test, "results/best_stacking", is_test=True, do_cross=False)
# Out:
# C:\Users\nicki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:1271: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   warnings.warn(
# classification train set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000    227565
#            1     1.0000    1.0000    1.0000    227339
#
#     accuracy                         1.0000    454904
#    macro avg     1.0000    1.0000    1.0000    454904
# weighted avg     1.0000    1.0000    1.0000    454904
# classification test set
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9998    0.9999     56750
#            1     0.9998    1.0000    0.9999     56976
#
#     accuracy                         0.9999    113726
#    macro avg     0.9999    0.9999    0.9999    113726
# ...
