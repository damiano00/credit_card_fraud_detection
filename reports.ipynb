# %%
import utils

# %%
dt = utils.get_model("best_decision_tree")
dt
# Out:
# Pipeline(memory='/tmp/tmp25p0adrn',
#          steps=[('scaler', MinMaxScaler()),
#                 ('classifier',
#                  DecisionTreeClassifier(max_features='sqrt', random_state=42))])

# %%
utils.evaluate_all_model(dt, "results/best_decision_tree")
# Out:
# classification train set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000    227565
#            1     1.0000    1.0000    1.0000    227339
#
#     accuracy                         1.0000    454904
#    macro avg     1.0000    1.0000    1.0000    454904
# weighted avg     1.0000    1.0000    1.0000    454904
# classification test set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000     56750
#            1     1.0000    1.0000    1.0000     56976
#
#     accuracy                         1.0000    113726
#    macro avg     1.0000    1.0000    1.0000    113726
# weighted avg     1.0000    1.0000    1.0000    113726
# Cross evaluation: [0.99602554 0.99818863 0.9983469  0.99836449 0.99845242 0.99555071
#  0.99781932 0.9979776  0.99806553 0.9983469 ]
# 0.9977138033519161 accuracy with a standard deviation of 0.0009863921117338336 in 10 folds

# %%
rf = utils.get_model("best_random_forest")
rf
# Out:
# Pipeline(memory='/tmp/tmpmjb8dhs6',
#          steps=[('scaler', MinMaxScaler()),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, n_jobs=-1,
#                                         random_state=42))])

# %%
utils.evaluate_all_model(dt, "results/best_random_forest")
# Out:
# classification train set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000    227565
#            1     1.0000    1.0000    1.0000    227339
#
#     accuracy                         1.0000    454904
#    macro avg     1.0000    1.0000    1.0000    454904
# weighted avg     1.0000    1.0000    1.0000    454904
# classification test set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000     56750
#            1     1.0000    1.0000    1.0000     56976
#
#     accuracy                         1.0000    113726
#    macro avg     1.0000    1.0000    1.0000    113726
# weighted avg     1.0000    1.0000    1.0000    113726
# Cross evaluation: [0.99602554 0.99818863 0.9983469  0.99836449 0.99845242 0.99555071
#  0.99781932 0.9979776  0.99806553 0.9983469 ]
# 0.9977138033519161 accuracy with a standard deviation of 0.0009863921117338336 in 10 folds

# %%
stacking = utils.get_model("best_stacking")
stacking
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(memory='/tmp/tmpyv84vzg5',
#                           steps=[('scaler', MinMaxScaler())])),
#                 ('stacking',
#                  StackingClassifier(estimators=[('rf',
#                                                  Pipeline(memory='/tmp/tmpmjb8dhs6',
#                                                           steps=[('scaler',
#                                                                   MinMaxScaler()),
#                                                                  ('classifier',
#                                                                   RandomForestClassifier(n_estimators=200,
#                                                                                          n_jobs=-1,
#                                                                                          random_state=42))])),
#                                                 ('dt',
# ...

# %%
utils.evaluate_all_model(dt, "results/best_stacking")
# Out:
# classification train set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000    227565
#            1     1.0000    1.0000    1.0000    227339
#
#     accuracy                         1.0000    454904
#    macro avg     1.0000    1.0000    1.0000    454904
# weighted avg     1.0000    1.0000    1.0000    454904
# classification test set
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000     56750
#            1     1.0000    1.0000    1.0000     56976
#
#     accuracy                         1.0000    113726
#    macro avg     1.0000    1.0000    1.0000    113726
# weighted avg     1.0000    1.0000    1.0000    113726
# Cross evaluation: [0.99602554 0.99818863 0.9983469  0.99836449 0.99845242 0.99555071
#  0.99781932 0.9979776  0.99806553 0.9983469 ]
# 0.9977138033519161 accuracy with a standard deviation of 0.0009863921117338336 in 10 folds
